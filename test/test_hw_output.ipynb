# %%
output = ['**Quest: Lines, Functions, and Their Graphs: Digital Art Exploration**\n\n---\n\n### Detailed Homework Instructions\n\n**Objective:**  \nThis homework is designed to enhance your understanding of lines, functions, and their graphs by integrating your interests and strengths in drawing and digital tools. You will visually explore mathematical concepts using digital art techniques to create engaging math visualizations that simplify and clarify important graphing ideas.\n\n**Part 1: Concept Understanding & Preparation**\n\n1. Review the concepts of:\n   - Lines and their equations (slope-intercept form, point-slope form)\n   - Basic functions (linear, quadratic, absolute value)\n   - Function transformations (shifting, stretching, reflecting)\n   - Combining functions (addition, subtraction)\n\n2. Use graph paper or graphing software (like Desmos) to sketch ideas before digitally recreating them.\n\n---\n\n**Part 2: Digital Art Creation**\n\n1. **Create a set of digital illustrations that visualize the following:**\n   - At least three different types of functions (linear, quadratic, absolute value).\n   - Each function should be shown in its original form and after at least two transformations (e.g., shift up/down, left/right, stretching, reflecting).\n   - Show at least one combination of functions (sum or difference) and graph it.\n\n2. **Use digital drawing tools** (such as Adobe Illustrator, Procreate, or any digital graphic software) to replicate your sketches:\n   - Incorporate your drawing strength by clearly defining lines and shapes.\n   - Use colors and styles to differentiate original functions from their transformed versions.\n   - Include labels that explain the transformation mathematically and visually.\n   - Embellish your graphs with digital visual techniques to enhance clarity and appeal (e.g., gradients, layering, textures).\n\n3. **Include brief explanations** adjacent to each digital graph:\n   - Describe the function type.\n   - Explain the effect of each transformation visually and mathematically.\n   - Interpret the meaning of the combined function graph.\n\n---\n\n**Part 3: Reflection**\n\n- Write a short paragraph (150–200 words) reflecting on how the act of visualizing these graphs digitally affected your understanding of the mathematical concepts.\n- Mention any challenges you faced, especially relating to integrating art and math.\n- Propose one idea for how you could extend this project in your portfolio.\n\n---\n\n### Submission Requirements\n\n- Submit a digital file (PDF or image format) comprising all your digital art graphs with labels and explanations.\n- Submit your reflection as a separate document.\n- Ensure your work is neat, visually organized, and effectively communicates the math principles through art.\n\n---\n\n### Rubric\n\n| Criteria                          | Excellent (4)                                                    | Good (3)                                                      | Satisfactory (2)                                               | Needs Improvement (1)                                          |\n|----------------------------------|-----------------------------------------------------------------|--------------------------------------------------------------|----------------------------------------------------------------|---------------------------------------------------------------|\n| **Mathematical Accuracy**         | All functions and transformations are mathematically correct.   | Minor errors in function representation or transformations.    | Several errors, but overall concepts are recognizable.          | Many errors that obscure understanding.                        |\n| **Visual Clarity & Creativity**   | Graphs are visually striking, clear, and creatively styled.      | Graphs are clear with moderate use of creative elements.      | Graphs are somewhat clear but lack visual creativity.            | Graphs are unclear or lack creative effort.                    |\n| **Integration of Art and Math**   | Effectively uses digital art to enhance understanding of math. | Art supports math concepts well, some missed opportunities.   | Basic use of art with limited enhancement of math understanding.| Little to no connection made between art and math concepts.   |\n| **Explanations & Labels**         | Explanations are thorough, clear, and insightful.                | Explanations clear but somewhat brief or general.             | Explanations present but lack clarity or depth.                  | Explanations are missing or confusing.                         |\n| **Reflection**                   | Insightful, well-articulated reflection on learning experience. | Reflection covers main points but lacks depth or insight.     | Reflection is brief and somewhat generic.                        | Reflection missing or off-topic.                               |\n| **Presentation & Submission**     | Professionally presented, well organized, correct file format.  | Neatly presented, minor organizational issues.                | Presentation is acceptable but could be clearer or more polished.| Poorly presented or incomplete submission.                    |\n\n---\n\nTake your time to explore and bring your unique artistic lens to this quest, using your strength in visual and digital skills to deepen your precalculus understanding!', '**Quest: Exploring Quadratics through Visual Storytelling**  \n**Skills: Quadratic and polynomial functions, their graphs; creating illustrated digital summaries**\n\n---\n\n### Detailed Homework Instructions:\n\n**Objective:**  \nCreate a visual storytelling project that explores the behavior and properties of quadratic functions through original digital illustrations. Your work will combine your strength in drawing and digital visual techniques to demonstrate your understanding of quadratic and polynomial functions, while supporting math learning through visual summaries.\n\n---\n\n### Step-by-step Instructions:\n\n1. **Research and Conceptual Understanding**  \n   - Review the key elements of quadratic and polynomial functions: standard form, vertex form, intercepts, axis of symmetry, direction of opening, and key features like max/min points and zeros.  \n   - Understand how these elements affect the graph and real-life applications of quadratic functions.\n\n2. **Plot Key Quadratic Functions**  \n   - Select at least three different quadratic functions with distinct graphs (e.g., different vertex positions, widths, and directions).  \n   - Using digital graphing tools or software (Desmos, GeoGebra, or any preferred digital tool), plot these functions clearly.\n\n3. **Create Illustrated Digital Summaries for Each Function:**  \n   For each quadratic function:  \n   - Illustrate its graph prominently. Use colors and styles to highlight important features such as vertex, x- and y-intercepts, axis of symmetry, and direction of opening.  \n   - Compose a short, visually engaging summary that explains the characteristics of the function and how its algebraic form relates to the graph features. Use callouts, labels, and symbols to make these points clear.  \n   - Include an analogy, metaphor, or story element to explain the function’s behavior (e.g., describing the parabola as a "bridge," "fountain," or "path of a ball").\n   - Use your drawing skills to embed these story elements into the visual design surrounding or integrated with the graphs.\n\n4. **Highlight the Polynomial Connection**  \n   - Create a separate digital panel that explains how quadratics fit into the broader class of polynomial functions.  \n   - Include polynomial basics and visuals that contrast quadratic functions with linear or cubic functions, if comfortable.\n\n5. **Synthesize into a Cohesive Digital Storyboard**  \n   - Organize all illustrations and summaries into a digital document or presentation format (e.g., PowerPoint, Google Slides, Canva).  \n   - Use a clean, logical flow that guides viewers through the major ideas of quadratic functions visually.  \n   - Incorporate your digital skills to enhance the clarity and appeal—use thoughtful layouts, graphics, and colors.\n\n6. **Final Reflection**  \n   - Write a brief reflection (100-150 words) on how creating visual summaries impacted your understanding of quadratics.  \n   - Discuss how your visual storytelling approach helped address any difficulties and how it connects to your long-term goals of integrating math with art.\n\n---\n\n### Deliverable Format:  \n- A digital portfolio file containing:  \n  - Three illustrated quadratic graphs with visual summaries  \n  - An explanatory panel on polynomial functions  \n  - Organized storyboard presentation of all work  \n  - Reflection paragraph  \n\nSubmit your final digital file via the class submission platform.\n\n---\n\n### Rubric for Assessment:\n\n| Criteria                          | Excellent (4)                                   | Good (3)                                      | Fair (2)                                    | Needs Improvement (1)                        |\n|----------------------------------|------------------------------------------------|----------------------------------------------|---------------------------------------------|----------------------------------------------|\n| Mathematical Accuracy            | All quadratic functions are correct and clearly explained, with thorough detail about vertex, intercepts, and graph features. | Most functions correctly graphed and explained with minor omissions. | Some inaccuracies in graphs and explanations; partial understanding evident. | Inaccurate or missing graphs and explanations; limited understanding. |\n| Visual Representation Quality    | Illustrations are highly creative, clear, and precise, effectively integrating artistic story elements. | Good quality drawings and visual storytelling, some minor clarity issues. | Basic illustrations with limited artistic integration. | Poorly drawn or unclear graphs and visuals. |\n| Use of Digital Tools             | Effective and skillful use of digital tools to enhance understanding and visual appeal. | Competent use of digital tools with some room for improvement. | Limited use of digital tools, reducing clarity or attractiveness. | Minimal or ineffective use of digital tools. |\n| Storytelling and Engagement       | Visual storytelling is imaginative and deeply connects math concepts to engaging narratives. | Storytelling is clear and supports math concepts adequately. | Storytelling is minimal or loosely connected to math ideas. | Lacks storytelling or engagement elements. |\n| Organization and Presentation    | Presentation is well-organized, visually balanced, and logically flows. | Generally organized with minor flow issues. | Some organizational issues affecting clarity. | Disorganized, confusing layout or format. |\n| Reflection                      | Thoughtful reflection demonstrating insight into learning and connection to personal goals. | Reflection adequately addresses learning and goals. | Superficial reflection with limited insight. | Missing or incomplete reflection. |\n\n---\n\n**Tips:**  \n- Use vibrant colors or thematic palettes to make your quadratics “come alive.”  \n- Experiment with digital brushes, layers, and effects to replicate professional visual summaries.  \n- Think of your project as a storybook about parabolas and quadratic functions that anyone can understand visually!\n\nGood luck, Golden Huang! This quest is a great opportunity to combine your math learning with your passion for drawing and digital art.', 'Here are the detailed homework instructions and rubric for the quest:\n\n**Quest Name:** Complex Numbers Connect: Digital Diagram Series  \n**Skills:** Complex numbers, zeros, Fundamental Theorem of Algebra; visualizing structure of solutions with digital graphics.\n\n---\n\n### Homework Instructions:\n\n**Objective:**  \nCreate a digital diagram series that visually connects the concepts of complex numbers, zeros of polynomial functions, and the Fundamental Theorem of Algebra. Your artwork should clarify the structure of solutions to polynomials by using digital drawing tools, integrating your strengths in replicating visual techniques and drawing with your interest in visual and digital learning.\n\n**Tasks:**\n\n1. **Research and Conceptualize:**\n   - Review the properties of complex numbers, including their representation in the complex plane.\n   - Understand zeros (roots) of polynomials, especially how complex roots come in conjugate pairs.\n   - Study the Fundamental Theorem of Algebra and how it guarantees the existence of roots.\n\n2. **Design the Diagram Series:**\n   - Create a series of at least 3 digital diagrams that illustrate:\n     - Representation of complex numbers on the complex plane.\n     - How polynomial zeros (real and complex) are located and plotted.\n     - Visualization of the structure of solutions to polynomials of degree 2 or higher, showing the relationship between coefficients and roots.\n   - Use colors, shapes, and spatial arrangements to enhance understanding.\n   - Include labels, legends, or annotations to guide the viewer’s comprehension.\n   - Incorporate your artistic skills to replicate or create advanced visual techniques digitally.\n\n3. **Integration with Math:**\n   - Each diagram must include mathematical content such as equations, formulas, or references to concepts like zeros, degree of polynomial, or complex conjugates.\n   - Explain briefly (1-2 sentences per diagram) how the visual elements represent the mathematical concepts.\n\n4. **Presentation:**\n   - Compile your diagrams and explanations into a single digital file or presentation format.\n   - Ensure clarity, coherence, and aesthetic appeal.\n   - Submit via the designated platform by the due date.\n\n---\n\n### Rubric:\n\n| Criteria                         | Excellent (4)                                       | Good (3)                                      | Fair (2)                                    | Needs Improvement (1)                       |\n|---------------------------------|----------------------------------------------------|-----------------------------------------------|---------------------------------------------|---------------------------------------------|\n| **Mathematical Accuracy**        | Correct and thorough representation of concepts including complex numbers, zeros, and Fundamental Theorem of Algebra. | Mostly correct; minor errors or omissions in concepts. | Some inaccuracies or major gaps in understanding present. | Concepts are incorrect or misunderstood significantly. |\n| **Visual Communication**         | Diagrams are clear, well-organized, visually engaging, and highly effective in illustrating the math concepts. | Diagrams are generally clear and organized, with minor improvements needed in visual appeal or clarity. | Diagrams are somewhat unclear or disorganized; visuals partially support math concepts. | Diagrams lack clarity, poor design, and do not support understanding. |\n| **Artistic Technique**           | Advanced digital drawing techniques used creatively to enhance comprehension and aesthetics. | Good use of digital tools and some creative elements evident. | Basic digital drawing skills demonstrated; limited creativity. | Poor use of digital tools; lacks creativity and effort. |\n| **Integration of Math and Art**  | Mathematical elements and annotations are seamlessly integrated with visual content, enhancing understanding. | Math and visuals are integrated, but connections could be stronger or clearer. | Some integration, but math and art feel separate or disjointed. | Lack of integration; visual and mathematical parts are disconnected. |\n| **Explanation and Clarity**      | Clear, concise, insightful explanations accompany each diagram, enhancing comprehension. | Explanations are clear but may lack depth or detail. | Explanations are vague or incomplete. | Explanations are missing or confusing. |\n\n---\n\nPlease focus on using your visual and digital strengths to produce an informative and aesthetically pleasing series that helps explain complex number concepts visually. This project will also help reinforce your understanding of challenging math topics through art.', 'Detailed Homework Instructions:  \n**Quest: Rational Functions Visual Guide**  \n**Skills: Rational functions, asymptotes, graphing; making poster-style digital diagrams**\n\n---\n\n### Objective:  \nCreate a visually engaging and educational digital poster that explains the key concepts of rational functions, including their definition, properties, types of asymptotes, and graphing techniques. Use your strengths in drawing and digital visual skills to make the material clear and accessible, helping both yourself and others understand rational functions better.\n\n---\n\n### Instructions:\n\n1. **Research and Review:**\n   - Start by reviewing the key concepts of rational functions from your precalculus materials, specifically focusing on:\n     - Definition and form of rational functions\n     - Vertical asymptotes: what causes them and how to find them\n     - Horizontal and slant (oblique) asymptotes: when they occur and how to determine them\n     - Behavior of rational functions near asymptotes\n     - Intercepts and domain restrictions\n     - Sketching graphs of rational functions including asymptotes and intercepts\n   - Use your digital precalc slides or PDFs on rational functions and asymptotes as references (such as "2.6 Rational Functions Asymptotes.ppt" and "2.7 Graphs of Rational Functions.pptx") for accurate content.\n\n2. **Outline Your Poster Content:**\n   - Divide the poster into sections addressing each of the key topics:\n     - Explanation of rational functions\n     - Vertical asymptotes (definition, example, visualization)\n     - Horizontal and Slant asymptotes (definition, examples, visual explanation)\n     - Steps for graphing a rational function (including domain, intercepts, asymptotes)\n     - Example graphs illustrating different types of rational functions\n   \n3. **Visual Design:**\n   - Use digital drawing tools (e.g., Adobe Illustrator, Photoshop, Procreate, or any other digital art software you are comfortable with) to create your poster.\n   - Combine hand-drawn elements with digital effects to enhance clarity and engagement.\n   - Use color coding to distinguish between vertical asymptotes, horizontal/slant asymptotes, and the function graph.\n   - Include clear labels, annotations, and step-by-step visuals for each concept.\n   - Ensure the poster is neat, well-organized, and aesthetically pleasing.\n\n4. **Mathematical Accuracy:**\n   - Include formulas and example functions with correct calculations.\n   - Show work supporting how vertical and horizontal/slant asymptotes are found for example rational functions.\n   - Graph examples should be accurate in shape and placement of asymptotes and intercepts.\n\n5. **Final Presentation:**\n   - Export your poster as a high-resolution digital image or PDF.\n   - The poster should be printable on a standard 11x17 inch page or viewable clearly on a digital device.\n   - Prepare a short written description (approx. 1-2 paragraphs) summarizing the content and explaining your visual choices.\n\n---\n\n### Rubric:\n\n| Criteria                          | Excellent (4)                                                                                                        | Good (3)                                                                                                  | Fair (2)                                                                                         | Needs Improvement (1)                                                     |\n|----------------------------------|---------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------|\n| **Mathematical Content**          | All key rational function concepts are accurately explained with correct examples and formulas.                      | Most key concepts explained, minor inaccuracies in examples or formulas.                                  | Some key concepts missing or significant errors in explanations or examples.                    | Many important concepts missing or incorrect information.                |\n| **Visual Clarity & Organization**| Poster is exceptionally clear and well-organized with distinct sections; information flows logically.                 | Poster is mostly clear and organized; minor lapses in flow or sectioning.                                  | Poster is somewhat disorganized or cluttered, making it difficult to follow.                     | Poster is confusing, cluttered, or poorly organized.                     |\n| **Visual Design & Creativity**   | Excellent use of color, labels, and drawings that enhance understanding; creative digital drawing techniques applied.| Good visual appeal and adequate use of color and graphics; some digital art techniques used.               | Basic visuals with minimal color or details; few creative or engaging design elements.           | Visual design is plain or messy with little to no digital art effort.    |\n| **Accuracy of Graphs**            | Graphs and asymptotes are accurately placed and clearly labeled; very precise and neat drawings.                      | Graphs mostly accurate with minor errors; labels mostly clear.                                             | Somewhat accurate graphs but with noticeable errors; labels unclear or missing.                 | Graphs incorrect or missing; asymptotes and labels not identifiable.     |\n| **Written Summary**               | Summary clearly explains mathematical concepts and design choices concisely and insightfully.                         | Summary explains most concepts and choices; could be clearer or more detailed.                             | Summary is brief or vague; some concepts or design reasons not addressed.                        | No summary provided or summary does not relate to poster content.       |\n\n---\n\n### Submission:\n\n- Submit your digital poster file along with your written summary document.\n- Ensure files are named using your full name and the quest title (e.g., "Golden_Huang_Rational_Functions_Visual_Guide.pdf").\n\n---\n\nBy completing this quest, you will visually reinforce your understanding of rational functions while integrating your drawing and digital skills to overcome difficulties with math visualization. This will contribute directly to your long-term goal of creating a digital visual math portfolio.', '### Homework Instructions for the Quest: Exponential & Logarithmic Curve Art\n\n**Objective:**  \nCreate a digital art project that explores exponential and logarithmic functions by blending mathematical graphing skills with creative digital drawing techniques. This project aims to reinforce your understanding of the properties and applications of these functions while leveraging your strengths in drawing and digital visual techniques.\n\n---\n\n**Part 1: Mathematical Exploration (50%)**  \n1. **Function Selection:** Choose at least two exponential functions and two logarithmic functions. Examples include:  \n   - \\( y = a \\cdot b^x \\) (exponential)  \n   - \\( y = \\log_b(x) \\) (logarithmic)  \n\n2. **Properties and Behavior:** For each function:  \n   - Identify key properties such as domain, range, asymptotes, and intercepts.  \n   - Plot accurate graphs using digital tools, showing the curve clearly on a coordinate plane.  \n   - Solve at least two equations involving each function (e.g., solving \\( 2^x = 8 \\) or \\( \\log_3(x) = 2 \\)) and show your work.\n\n3. **Real-world Modelling:** Write a short paragraph explaining a real-world example modeled by one exponential and one logarithmic function (e.g., population growth for exponential, pH scale for logarithmic).\n\n---\n\n**Part 2: Creative Digital Art (50%)**  \n1. **Integration of Graph and Art:**  \n   - Use your chosen digital drawing tools to creatively incorporate the graphs of these functions into a digital artwork.  \n   - Blend the mathematical curves with imagery or themes that reflect their real-world application or conceptual meaning. For example, growing plants for exponential growth or sound waves for logarithmic scale.  \n   - Experiment with color, shading, and layering to emphasize the mathematical curves within your art.\n\n2. **Visual Explanation:**  \n   - Include annotations or labels on your artwork to highlight important features of the graphs (e.g., asymptotes, intercepts).  \n   - Use your drawing skills to replicate and enhance visual cues to explain the behavior of the functions clearly.\n\n3. **Final Presentation:**  \n   - Compose a brief artist’s statement (100-150 words) describing your creative process, how you integrated the math concepts, and what the artwork communicates about exponential and logarithmic functions.\n\n---\n\n### Rubric\n\n| Criteria                             | Excellent (90-100%)                           | Good (75-89%)                             | Fair (60-74%)                              | Needs Improvement (<60%)                  |\n|------------------------------------|---------------------------------------------|------------------------------------------|--------------------------------------------|------------------------------------------|\n| **Mathematical Accuracy**           | All functions correctly graphed; equations solved accurately; thorough explanation of properties and real-world applications.| Minor errors in graph accuracy or equation solving; explanations generally clear.| Several errors in graph, equations, or properties; explanations somewhat unclear or incomplete.| Major errors with graphs or solutions; limited or incorrect explanations. |\n| **Integration of Art & Math**       | Seamless, creative blending of math curves and digital art; effectively communicates math concepts visually.| Good blending with some creative elements; math concepts mostly clear through art.| Some attempt at integration but lacks creativity or clarity in visual math communication.| Limited or no integration of math into art; unclear or minimal visual communication of math concepts.|\n| **Visual & Digital Techniques**     | Excellent use of digital tools and artistic techniques; clean, engaging, and well-composed artwork.| Good digital technique; artwork is visually appealing with minor issues.| Basic use of digital tools; artwork lacks polish or clear focus.| Poor digital execution; artwork is messy or lacks visual interest.|\n| **Explanation & Presentation**      | Clear, insightful artist’s statement; thorough annotations enhancing understanding.| Good statement with relevant details; annotations mostly clear.| Basic statement with limited insight; annotations somewhat helpful.| Minimal or missing statement; annotations unclear or absent.|\n\n---\n\n### Submission\n\n- Submit your digital artwork file(s) with clear labels in your digital portfolio.\n- Include scanned or digital copies of your solved equations and graphs.\n- Attach your artist’s statement as a text document or within the digital file.\n\n---\n\n**Deadline:** [Insert due date here]\n\nFocus on combining your strong visual and digital skills with mathematical understanding to create a stunning and educational project that visually explains exponential and logarithmic concepts!', 'Quest: Trigonometry in Art: Circle and Waves  \nSkills: Radians, degrees, unit circle, right triangle trigonometry; visualizing angles and triangles in digital form.\n\n---\n\n### Detailed Homework Instructions:\n\n**Objective:**  \nCreate a visually engaging digital artwork that illustrates trigonometric concepts through the theme of circles and waves. This project will strengthen your understanding of radians, degrees, the unit circle, and right triangle trigonometry by integrating these mathematical ideas with your drawing and digital visualization skills.\n\n---\n\n#### Part 1: Study and Sketch (Preliminary Work)  \n1. **Review key concepts:**\n   - Understand the relationship between radians and degrees.\n   - Explore the unit circle, noting how angles correspond to points (cosine and sine values).\n   - Review right triangle trigonometry and how angle measures translate to sine, cosine, and tangent ratios.\n2. **Sketch your ideas** on paper or digitally:\n   - Draw the unit circle showing key angles in both radians and degrees.\n   - Sketch right triangles inside or related to the unit circle illustrating sine, cosine, and tangent as lengths.\n   - Illustrate basic wave shapes representing sine and cosine functions along a horizontal axis.\n\n---\n\n#### Part 2: Digital Visual Art Creation  \nUse your preferred digital drawing software to create a polished piece that includes the following elements:  \n1. **Unit Circle Display:**\n   - Draw a clean, colorful unit circle.\n   - Mark angles in both degrees and radians at least at: 0°, 30°, 45°, 60°, 90°, 180°, 270°, and 360°.\n   - Illustrate the coordinate points on the circle for these angles with their sine (y-coordinate) and cosine (x-coordinate) values.\n2. **Right Triangle Representation:**\n   - Show at least two right triangles within or adjacent to the unit circle.\n   - Clearly label the sides opposite, adjacent, and hypotenuse.\n   - Indicate the angle in radians or degrees and corresponding sine, cosine, and tangent values visually.\n3. **Waveforms:**\n   - Create sine and cosine wave graphs beneath or next to the unit circle.\n   - Plot at least one full period of each wave.\n   - Show how these waves correspond visually to the rotation around the unit circle.\n4. **Angle Visualization:**\n   - Use visuals like arrows or shading to show angle rotations on the circle and corresponding points on the waveform.\n   - Include a brief visual legend or labels to help viewers understand the connections.\n5. **Artistic Elements:**\n   - Use your drawing skills creatively to enhance the visual appeal (color harmony, digital brush effects, layering).\n   - Incorporate themes of circles, waves, and right triangles artistically while ensuring the math is accurate and understandable.\n\n---\n\n#### Part 3: Reflection and Explanation  \nWrite a short digital caption or accompanying text (150-250 words) explaining how your artwork represents the trigonometric concepts. Highlight how the circle, angles, triangles, and waves relate to one another and how you visually expressed radians and degrees.\n\n---\n\n### Rubric:\n\n| Criteria                       | Excellent (4)                                   | Good (3)                                     | Satisfactory (2)                              | Needs Improvement (1)                         |\n|-------------------------------|------------------------------------------------|----------------------------------------------|----------------------------------------------|----------------------------------------------|\n| **Mathematical Accuracy**     | All angles, radians, sine/cosine values correct; unit circle and triangles labeled precisely and clearly. | Mostly correct with minor errors in angle or trigonometric values. | Some errors in values or labeling; understanding is partial. | Incorrect or missing values and labels; poor conceptual grasp. |\n| **Visual Clarity & Organization** | Elements are clearly arranged and easy to understand; connections between parts are well shown. | Mostly clear but layout or labels could be improved for easier understanding. | Somewhat cluttered or confusing layout; connections unclear. | Disorganized layout or missing critical labels; very hard to follow. |\n| **Creativity and Digital Technique** | Artwork is visually striking with original use of digital media and drawing skills enhancing math concepts. | Good use of digital tools and creative elements with moderate enhancement. | Basic digital drawing with limited creativity or use of tools. | Little to no creative effort or poor digital execution. |\n| **Reflection and Explanation** | Clear, concise, insightful explanation connecting art and trigonometry concepts. | Good explanation with a reasonable connection to the artwork. | Explanation is vague or partially relevant. | Missing, unclear, or unrelated explanation. |\n\n---\n\n### Submission Guidelines:  \n- Submit the final digital artwork file in PNG, JPEG, or PDF format.  \n- Include your reflection either embedded in the image or in a separate text document.  \n- Ensure your name and date are included on the artwork or in the file metadata.\n\n---\n\nThis project combines your strengths in digital drawing and visual learning with your goal to visually explain precalculus concepts. It will deepen your understanding of trigonometry while allowing you to creatively express mathematical ideas through art.', '**Quest: Sine & Cosine Digital Graph Gallery**\n\n**Objective:**  \nCreate a digital gallery that showcases your understanding and artistic interpretation of sine and cosine functions. This project focuses on graphing sine and cosine functions, applying transformations, exploring inverse trigonometric functions, and expressing these concepts through animated digital art featuring wave patterns.\n\n---\n\n### Detailed Instructions\n\n1. **Graphing Sine and Cosine Functions**  \n   - Begin by graphing the basic sine and cosine functions using digital graphing tools (e.g., Desmos, GeoGebra, or digital drawing software with graphing capability).  \n   - Illustrate at least two full periods of each function clearly showing amplitude, period, and midline.\n\n2. **Transforming Trigonometric Functions**  \n   - Create graphs showing transformations of sine and cosine, including:  \n     - Amplitude changes: y = A sin(x) and y = A cos(x), where A ≠ 1  \n     - Period changes: y = sin(Bx) and y = cos(Bx), where B ≠ 1  \n     - Phase shifts: y = sin(x - C) and y = cos(x - C)  \n     - Vertical shifts: y = sin(x) + D and y = cos(x) + D  \n   - Produce at least two examples for each type of transformation, overlaying or directly comparing to the original function.\n\n3. **Inverse Trigonometric Functions**  \n   - Include at least one graph of an inverse sine (arcsin) and inverse cosine (arccos) function, explaining their domain and range restrictions visually.  \n   - Depict how the inverse functions "undo" the sine and cosine functions.\n\n4. **Animated Art of Wave Patterns**  \n   - Using a digital animation tool or software (such as Adobe Animate, Procreate animation features, or similar), create an animation to visually represent how sine and cosine waves evolve over an interval.  \n   - The animation should highlight key features such as peaks, troughs, zeros, and periodicity.  \n   - Integrate creative visual effects or thematic elements that enhance the understanding of wave behavior.\n\n5. **Artistic and Digital Presentation**  \n   - Combine all these elements into a cohesive digital gallery presentation.  \n   - Use your drawing skills to digitally enhance the graphs with color coding, thematic backgrounds, and labels that are visually clear and informative.  \n   - Your presentation can be in the form of a digital slideshow, interactive webpage, or digital portfolio with embedded animations and illustrations.\n\n6. **Explanation and Reflection**  \n   - Write a concise artist statement or reflection (around 200–300 words) describing how the mathematical concepts guided your artistic choices.  \n   - Explain how your visual and digital skills helped you understand and communicate the properties of sine, cosine, and their transformations.\n\n---\n\n### Rubric\n\n| Criteria                          | Excellent (4)                                                | Good (3)                                             | Satisfactory (2)                                    | Needs Improvement (1)                         |\n|----------------------------------|--------------------------------------------------------------|-----------------------------------------------------|----------------------------------------------------|----------------------------------------------|\n| **Accuracy of Graphs**            | All graphs correctly depict sine/cosine functions and transformations with precise scale and features | Most graphs are accurate; minor errors in scale or feature representation  | Basic understanding shown; multiple errors in graphs | Graphs are mostly inaccurate or unclear       |\n| **Inverse Function Representation** | Inverse trig graphs correctly shown with clear domain/range and visual explanations | Inverse trig graphs included with some minor inaccuracies or unclear visuals | Included inverse trig graphs but with significant errors | Inverse trig functions missing or incorrect   |\n| **Animation Quality and Relevance** | Animation is smooth, clear, and creatively illustrates wave behavior and key features | Animation good quality, depicts sine/cosine waves but lacks some clarity or creativity | Animation included but simplistic or partially unclear | No animation or animation is irrelevant/confusing |\n| **Artistic Enhancement & Visual Appeal** | Graphs and gallery are creatively presented with excellent use of digital drawing to enhance understanding  | Good artistic layering and aesthetic; mostly clear and visually engaging | Basic visual elements added; some clarity issues | Minimal or no effort in artistic presentation |\n| **Digital Integration & Cohesion** | All elements are seamlessly integrated into a professional, cohesive digital gallery | Mostly well-integrated; minor issues with flow or consistency | Some integration, but elements feel disconnected | Disorganized or incomplete digital presentation |\n| **Reflection & Explanation**     | Insightful reflection linking math concepts and artistic choices clearly and thoughtfully | Clear reflection with good connection to math and art | Basic reflection with limited connection between math and art | Reflection missing or unclear connections      |\n\n---\n\nThis project combines your strengths in drawing and digital work with your goal of visually understanding and representing precalculus concepts, helping to reinforce the math while growing your digital artistry. Enjoy the process of blending math and art in a dynamic, creative way!', '### Homework Instructions for Quest: Trigonometric Identities Illustrated\n\n**Objective:**  \nCreate a clear, visually appealing infographic that illustrates key trigonometric identities, demonstrates how to use and verify these identities, solves trig equations using them, and explains sum and difference formulas through effective visual transformations.\n\n---\n\n### Detailed Instructions:\n\n1. **Choose Your Identities:**  \n   Select at least 5 fundamental trigonometric identities from the following categories:  \n   - Pythagorean identities  \n   - Reciprocal identities  \n   - Quotient identities  \n   - Sum and difference formulas  \n   - Double-angle or half-angle formulas (optional for extra points)\n\n2. **Verification and Explanation:**  \n   For each identity, write a short but precise algebraic verification that clearly shows why the identity holds true. Include step-by-step solutions.\n\n3. **Solving Trigonometric Equations:**  \n   Choose 2 equations that can be solved using the identities you selected. Solve these equations step-by-step, demonstrating the use of identities to simplify or rearrange terms.\n\n4. **Visual Representation:**  \n   - Create digital drawings, charts, or diagrams that visually explain each identity.  \n   - Use your drawing skills and digital visualization tools to replicate the geometric or algebraic transformations involved. For example, use unit circles, graphs of sine and cosine, or angle addition illustrations.  \n   - Represent the transformations or simplifications that occur when applying sum/difference formulas with stepwise, annotated visuals.\n\n5. **Infographic Composition:**  \n   - Design an infographic page or digital poster that organizes your work logically and attractively.  \n   - Use colors, labels, and digital icons or symbols to highlight key elements.  \n   - Make sure the infographic is self-explanatory to someone learning these identities for the first time.\n\n6. **Submission:**  \n   Submit the finalized infographic as a high-quality digital image or PDF file. Include your algebraic work alongside the visuals for completeness.\n\n---\n\n### Rubric for Trigonometric Identities Illustrated\n\n| Criteria                         | Excellent (4)                                            | Good (3)                                         | Satisfactory (2)                                  | Needs Improvement (1)                           |\n|---------------------------------|----------------------------------------------------------|-------------------------------------------------|-------------------------------------------------|------------------------------------------------|\n| **Identities Selection & Verification** | Correctly selects and verifies 5+ identities clearly and logically with full algebraic steps | Verifies 4 identities with minor errors or unclear steps | Verifies 3 identities but with some errors or incomplete explanations | Verifies fewer than 3 or with major errors      |\n| **Solving Trigonometric Equations** | Solves 2 equations correctly demonstrating identity use with clear, logical steps | Solves 2 equations with minor calculation errors | Solves 1 equation correctly or 2 with major errors | Fails to solve equations or no use of identities  |\n| **Visual Representations**       | Creative, accurate, and clear digital visuals that enhance understanding; effectively use drawings to illustrate transformations | Visuals are clear but less creative or somewhat incomplete | Visuals are basic and occasionally unclear or disconnected from content | Visuals are missing or irrelevant                 |\n| **Infographic Design and Clarity**  | Very well-organized, visually appealing, easy to follow; excellent digital design and labeling | Organized and mostly clear with good use of digital design | Some organization and clarity issues, mediocre design | Disorganized, confusing, poor or no digital design |\n| **Integration of Concepts**      | Smooth and insightful integration of identities, solutions, and visuals into a single cohesive infographic | Good integration with minor disconnects    | Partial integration; some elements feel isolated | Lacks integration; disparate pieces with no flow  |\n\n---\n\nFocus on combining your strengths in drawing and digital visualization to make math concepts come alive visually, especially illustrating how and why the identities work. Use colors, layering, and transforms to guide viewers through the math visually. Good luck!', 'Here are the detailed homework instructions and rubric for the quest "Law of Sines and Cosines in Action," focusing on skills including laws of sines and cosines, solving triangles, introduction to vectors, and dot products — illustrated by scenes showing solutions to triangle problems:\n\n---\n\n### Homework Instructions: Law of Sines and Cosines in Action\n\n**Objective:**  \nCreate a visual and digital art project that demonstrates your understanding and application of the Law of Sines, Law of Cosines, solving triangles, introductory vector concepts, and dot products. Use your drawing and digital skills to illustrate solutions to triangle problems. This project will help deepen your comprehension of these mathematical concepts through visualization.\n\n**Materials Needed:**\n- Digital drawing tools (e.g., drawing tablet, Procreate, Adobe Illustrator, or similar)\n- Graph paper or digital graphing software for initial sketches\n- Calculator or software for mathematical computations\n\n**Steps:**\n\n1. **Select Triangle Problems:**  \n   Choose three different triangle problems involving the Law of Sines and Law of Cosines. Problems should vary in complexity — for example, one using the Law of Sines to find missing sides or angles, another applying the Law of Cosines, and a mixed problem requiring solving the triangle fully.\n\n2. **Solve Triangles Mathematically:**\n   - Calculate all missing sides and angles for each triangle using the appropriate law.\n   - Include steps with equations, substitutions, and results for clarity.\n\n3. **Intro to Vectors and Dot Products:**\n   - For at least one of the triangles, represent the sides as vectors.\n   - Calculate the dot product where applicable, explaining its significance (e.g., finding the angle between two vectors).\n   - Illustrate this vector interpretation with arrows and labels in your drawing.\n\n4. **Create Illustrated Scenes:**\n   - Visually depict each triangle problem you solved. Draw the triangles to scale or relative scale.\n   - Label all known and found sides and angles clearly.\n   - Use digital tools to add elements such as angle arcs, vector arrows, and side length annotations.\n   - Include a brief caption or annotation next to each illustration explaining the solution method and results.\n\n5. **Combine into a Portfolio Page:**\n   - Arrange your three illustrated triangle problems into a clean, visually appealing digital page or slide.\n   - Ensure your work is easy to follow for someone learning the topic.\n   - Use color coding or distinct styles to differentiate between sines, cosines, and vector parts.\n\n6. **Reflection:**\n   - Write a short reflection (about 150-200 words) on how visualizing the math concepts helped your understanding.\n   - Mention any challenges you faced and how using your drawing skills aided in overcoming them.\n\n---\n\n### Rubric for the Homework\n\n| Criteria                         | Exceeds Expectations (4)                                           | Meets Expectations (3)                                            | Approaching Expectations (2)                                      | Needs Improvement (1)                                             |\n|---------------------------------|-------------------------------------------------------------------|------------------------------------------------------------------|------------------------------------------------------------------|------------------------------------------------------------------|\n| **Mathematical Accuracy**         | All triangle problems are solved correctly with clear steps      | Most problems are solved correctly with minor errors             | Several calculation errors or unclear steps                      | Many errors, missing or incorrect calculations                   |\n| **Application of Laws**           | Clear and correct use of both Law of Sines and Law of Cosines    | Correct use of laws in problems, with minor application issues   | Partial or inconsistent use of laws                              | Misuse or lack of application of laws                            |\n| **Vector and Dot Product**        | Effectively represents vectors, calculates dot products accurately, and explains their meaning     | Represents vectors and calculates dot products with some errors  | Incomplete or inaccurate vector work                             | No vector or dot product work shown or incorrect                 |\n| **Visual Illustration Quality**  | Professionally drawn digital illustrations; clear, labeled, and visually engaging                   | Clear and neat illustrations with appropriate labels             | Illustrations present but lack clarity or labels                | Illustrations missing or unclear                                 |\n| **Integration of Math and Art**  | Seamlessly integrates math concepts into creative digital drawings                                     | Integrates concepts and visuals clearly                           | Limited integration, visuals do not reinforce math understanding | No meaningful integration of visuals and math                   |\n| **Reflection Quality**            | Insightful reflection showing understanding of the learning process                                | Reflection explains learning with some insight                   | Reflection present but lacks depth                               | Reflection missing or off-topic                                 |\n| **Presentation/Organization**   | Portfolio page well-organized, visually balanced, and easy to follow                               | Organized with minor layout or clarity issues                    | Some organization but confusing layout                          | Disorganized or incomplete presentation                         |\n\n---\n\nThis assignment supports both your strengths in drawing and digital visual work and addresses mathematical concepts visually, helping you overcome your math weakness through art integration.\n\nIf you need additional guidance or examples from the class materials (Unit 6 presentations on Law of Sines, Law of Cosines, Vectors, and Dot Products), please let me know! This homework leverages your visual/digital learning style and interests to build your precalculus portfolio with a blend of math and art.\n\n---\n\nWould you like me to provide a step-by-step example or template for the illustrated solution of a specific triangle problem using Law of Sines or Cosines?', "Homework for Quest: Vectors in Art & the Trig Form of Complex Numbers\n\nDetailed Instructions:\n\n1. Overview:\n   This homework is designed to integrate your artistic skills with mathematical concepts of vectors and the trigonometric form of complex numbers. Your task is to apply vector operations and represent complex numbers in trig form, using digital drawing tools to create interactive diagrams that visually demonstrate these concepts.\n\n2. Part 1: Applying Vectors in Artistic Composition\n   - Choose an original or existing digital artwork or create a new drawing that strongly incorporates vectors as directional elements.\n   - Identify at least three key vectors within your artwork. For each vector, calculate and digitally illustrate:\n     a. The magnitude and direction.\n     b. The dot product between pairs of vectors.\n     c. The cross product between pairs of vectors (indicating the resulting vector direction and magnitude).\n   - Use color coding and annotations in your digital diagram to enhance clarity.\n   - Provide brief written explanations (2-3 sentences each) on how these vector operations affect the composition's dynamics and spatial relationships.\n\n3. Part 2: Trig Form of Complex Numbers in Digital Art\n   - Select at least five complex numbers relevant to your artwork’s vector components.\n   - Convert these complex numbers from rectangular form (a + bi) into trigonometric form (r(cosθ + i sinθ)) and represent them visually using digital diagrams.\n   - Integrate these trigonometric representations into your artwork or a standalone digital infographic.\n   - Illustrate how transformations in your artwork (such as rotations or scaling) relate to the trig form of complex numbers.\n   - Include interactive elements if possible (e.g., overlays or sliders to change angles or magnitudes, demonstrating the impact on vectors).\n\n4. Tools and Format:\n   - Use digital drawing software that supports layers and annotations (e.g., Adobe Illustrator, Procreate with digital annotations, or any interactive vector diagram tool).\n   - Submit your work as a high-resolution digital file (PNG, PDF, or an interactive digital format).\n   - Alongside your digital artwork, submit a brief report (approximately 500 words) explaining your process, calculations, and artistic choices.\n\n5. Submission:\n   - Ensure your files are clearly labeled with your name and quest title.\n   - Submit through the designated platform by the due date.\n\nRubric:\n\n| Criteria                     | Excellent (4)                                               | Good (3)                                                | Satisfactory (2)                                             | Needs Improvement (1)                                       |\n|------------------------------|-------------------------------------------------------------|---------------------------------------------------------|---------------------------------------------------------------|-------------------------------------------------------------|\n| Vector Application           | Accurately calculates and visually represents magnitude, direction, dot and cross products with clear annotations and color coding. | Correct calculations and representations with minor annotation or clarity issues. | Basic accuracy in calculations and representations with limited annotations.  | Incomplete or incorrect calculations, unclear representations. |\n| Trig Form of Complex Numbers | Converts all complex numbers correctly to trig form; visually integrates them with interactive elements effectively demonstrating transformations. | Mostly correct conversions and visual integration; some interactive elements included but may lack clarity. | Converts some numbers correctly; limited visual or interactive representation. | Incorrect conversions; lacks visual or interactive elements. |\n| Artistic and Digital Quality | Digital diagrams are visually appealing, clear, well-organized, and creatively enhance mathematical understanding. | Diagrams are neat and organized; good aesthetic and clarity.  | Diagrams are somewhat clear but lack polish or creative integration. | Diagrams are cluttered, unclear, or poorly executed.         |\n| Explanations and Report      | Provides insightful, concise explanations connecting math and art; report is clear, well-written, and thorough. | Explanations clear but less detailed; report covers key points adequately. | Basic explanations; report lacks depth or clarity.            | Explanations missing or unclear; report incomplete or poorly written. |\n| Submission and Presentation  | On time, correctly labeled, and professionally presented.    | On time and labeled, minor presentation issues.         | Late or labels missing; presentation is basic.                | Late submission, missing labels, or poor presentation.       |\n\nUse this homework to deepen your understanding of how vectors and complex numbers can be visually represented and creatively applied in digital art, enhancing both your math comprehension and artistic expression.", 'Homework Instructions for Quest: Matrices and Multivariable Visualizations\n\nObjective:\nCreate a comprehensive and visually engaging project that demonstrates your understanding of matrices, their inverses and determinants, applications to systems of equations, and multivariable concepts. Utilize your strengths in drawing and digital visual techniques to develop clear visual flowcharts and storyboards that explain each matrix operation and multivariable concept step-by-step.\n\nDetailed Instructions:\n\n1. Understanding and Representing Matrices\n- Draw digital representations of various types of matrices used in class (e.g., 2x2, 3x3).\n- Illustrate how matrices are constructed and their components (rows, columns).\n- Create diagrams that differentiate between different matrix sizes and types.\n\n2. Showing Matrix Operations\n- Visually explain how to calculate the determinant of a 2x2 and 3x3 matrix via stepwise flowcharts.\n- Diagrammatically show the calculation process for matrix inverses, including any necessary conditions (invertibility).\n- Include visual comparisons of original matrices and their inverses to show their relationship clearly.\n\n3. Solving Systems Using Matrices\n- Develop a visual storyboard that solves a system of linear equations using matrix operations (e.g., using inverses or Cramer’s Rule).\n- Show each step clearly: setting up the augmented matrix, applying operations, and interpreting the solution visually.\n\n4. Exploring Multivariable Concepts\n- Illustrate how matrices represent multivariable transformations or linear mappings.\n- Provide diagrams demonstrating effects such as rotations, scalings, or shears on coordinate planes.\n- Use visual examples to explain concepts of dimensions, vectors, and how multivariable functions interact.\n\n5. Creating Visual Flowcharts and Storyboards\n- Use your digital tools to organize all matrix operations and multivariable concepts into intuitive flowcharts.\n- Label each step with concise explanations that show the mathematical reasoning behind the operation.\n- Ensure flowcharts and storyboards are sequential and allow viewers to follow logical progressions easily.\n\nSubmission Requirements:\n- A digital portfolio file (PDF, PowerPoint, or a digital art portfolio format) compiling all drawings, flowcharts, storyboards, and explanations.\n- Use clear, legible fonts and color coding to enhance understanding.\n- Submit your work through the designated platform by the due date.\n\nRubric:\n\n| Criteria                       | Excellent (4)                                         | Good (3)                                             | Satisfactory (2)                                    | Needs Improvement (1)                              |\n|-------------------------------|------------------------------------------------------|-----------------------------------------------------|----------------------------------------------------|---------------------------------------------------|\n| Accuracy of Mathematical Content | Matrix calculations, determinants, inverses, and systems solving are completely accurate with no errors | Minor errors in calculations or explanations that do not impede overall understanding | Several errors that indicate partial misunderstanding but overall concept is communicated | Significant errors that misrepresent key mathematical concepts |\n| Visual Clarity and Creativity | Flowcharts and storyboards are highly clear, creatively visualized, and engaging, demonstrating strong digital drawing skills | Clear visuals with good creativity; mostly easy to follow | Visuals are somewhat clear but lack detail or creativity | Visuals are confusing, unclear, or incomplete |\n| Explanation and Labels         | All steps are clearly labeled with thorough, easy-to-understand explanations | Most steps labeled and explained well | Some steps labeled, with explanations that occasionally lack clarity | Steps are unlabeled or explanations are missing or confusing |\n| Integration of Multivariable Concepts | Multivariable visualizations are detailed and clearly connected to matrix operations | Multivariable concepts included with reasonable clarity | Some inclusion of multivariable visuals but poorly connected | Multivariable concepts missing or poorly illustrated |\n| Use of Digital Tools           | Excellent use of digital drawing tools to enhance visual explanations | Good use of digital tools; visuals are enhanced but could improve | Basic use of digital tools without enhancing explanations | Little or no use of digital tools; visuals are dull or unclear |\n\nFocus on leveraging your drawing and digital visual strengths to overcome difficulties with math by transforming abstract matrix concepts into vivid, understandable visuals. This project will build toward your long-term goal of creating a digital visual math portfolio that uniquely blends your artistic skills with mathematical concepts.', '**Quest: Sequences & Series Story Art**  \n**Skills:** Recognizing and visualizing sequences and series (arithmetic/geometric); infographics and creative stepwise art illustrating processes.\n\n---\n\n### Detailed Instructions:\n\n1. **Objective:**  \n   Create a sequential visual art story (a series of images or a comic-style infographic) that explains the concept of arithmetic and geometric sequences and series. This project should combine your strengths in drawing and digital art with your interest in visual learning to represent mathematical ideas clearly and creatively.\n\n2. **Part 1: Concept Exploration**  \n   - Begin by summarizing the key definitions and formulas for arithmetic and geometric sequences and series:\n     - Arithmetic sequence: \\( a_n = a_1 + (n-1)d \\)\n     - Arithmetic series sum: \\( S_n = \\frac{n}{2} (a_1 + a_n) \\)\n     - Geometric sequence: \\( a_n = a_1 \\cdot r^{n-1} \\)\n     - Geometric series sum: \\( S_n = a_1 \\frac{1-r^n}{1-r} \\) for \\( r \\neq 1 \\)\n   - Visualize these concepts using simple iconography or symbolic representations to anchor the math visually.\n\n3. **Part 2: Visual Storytelling**  \n   - Create a stepwise illustration or infographic that narrates an original story or scenario where arithmetic and geometric sequences appear naturally (e.g., counting steps, stacking objects, population growth).\n   - Each step in the sequence or term in the series should be visualized clearly, showing the progression and pattern.\n   - Use your drawing and digital tools to replicate and enhance visual techniques: color gradients to show growth or change, patterns or shapes that represent terms, arrows or connectors to indicate relationships between terms, etc.\n\n4. **Part 3: Infographic Design**  \n   - Design a clean, visually appealing infographic that includes:\n     - The formulas with annotated visuals explaining each component.\n     - A comparison section that visually contrasts arithmetic and geometric sequences.\n     - An explanation part that describes how to find sums of these series, showing partial sums visually.\n   - Use digital design principles (balance, alignment, contrast) to make the information engaging and accessible.\n\n5. **Part 4: Reflective Summary**  \n   - Write a short artist’s reflection (about 150-200 words) describing how you represented the sequences and series visually.\n   - Explain any challenges you faced translating mathematical concepts into visual art.\n   - Reflect on how this project helped you understand or overcome weaknesses in math through your strengths in drawing and digital creativity.\n\n---\n\n### Rubric for Sequences & Series Story Art\n\n| Criteria                    | Excellent (4)                                               | Good (3)                                                  | Satisfactory (2)                                        | Needs Improvement (1)                                  |\n|-----------------------------|-------------------------------------------------------------|-----------------------------------------------------------|---------------------------------------------------------|--------------------------------------------------------|\n| **Mathematical Accuracy**    | All formulas and sequence/series concepts are correct and clearly explained visually. | Minor inaccuracies but overall concepts are clearly conveyed. | Some formulas/concepts partially incorrect or unclear.  | Many inaccuracies or misconceptions about sequences/series. |\n| **Visual Storytelling**      | Creative, clear, and engaging stepwise visuals that effectively illustrate the sequence concepts. | Visual story mostly clear with minor lapses in creativity or clarity. | Visual story is somewhat clear but lacks engagement or coherence. | Visuals are confusing or do not clearly illustrate the sequences/series. |\n| **Infographic Design & Clarity** | Excellent use of digital art principles with strong organization and aesthetic appeal. | Good design and organization, some areas could improve in clarity or visual appeal. | Basic design principles used, but infographic is cluttered or hard to follow. | Poor design, lacks organization, and is visually confusing. |\n| **Integration of Drawing Skills** | Demonstrates strong digital drawing skills with effective use of color, shape, and replicating visual techniques. | Competent drawing skills with some good usage of visual techniques. | Basic drawing is used but lacks refinement or creativity. | Minimal effort in drawing and visual techniques, lacks polish. |\n| **Reflective Summary**       | Insightful reflection connecting the visual art created with mathematical understanding and personal learning. | Clear reflection showing some connection between art and math understanding. | Reflection is superficial or vague about the learning process. | Missing or very limited reflection on the project. |\n\n---\n\nUse your digital and visual strengths to make this math topic come alive through your art. Focus on clarity and creativity to make your infographic both educational and visually enjoyable.', 'Detailed Homework Instructions for the Quest:\n**Binomial Theorem & Counting Principles Collage**\n\n---\n\n### Objective:\nCreate a visually engaging collage that demonstrates your understanding and skill in expanding binomials, applying counting principles, and interpreting probability. Use overlayed diagrammatic art that clearly illustrates combinatorial concepts and the binomial theorem. This project integrates your drawing strengths and visual/digital learning style with your precalculus content.\n\n---\n\n### Instructions:\n\n1. **Mathematical Content:**\n   - Choose at least three different binomial expansions to fully expand using the Binomial Theorem.\n   - Incorporate counting principles by including examples that demonstrate permutations, combinations, and the fundamental counting principle.\n   - Include at least two probability problems where counting principles and binomial expansions are used to find probabilities.\n   - Show your work mathematically clearly for the expansions, counting computations, and probability solutions.\n\n2. **Visual Representation:**\n   - Create a collage that graphically represents the concepts you worked through.\n   - Use diagrams such as Pascal’s Triangle, tree diagrams, or lattice/grid representations to illustrate counting principles.\n   - Use overlay effects to combine mathematics visuals with digital drawing art that highlights patterns, symmetry, or visual explanations of the binomial theorem and counting.\n   - Labels and annotations should explain the mathematical ideas visually.\n\n3. **Format & Tools:**\n   - Use digital drawing tools (e.g., drawing tablets, graphic design software, apps) to create your collage.\n   - Ensure the collage is neat, colorful, and easy to follow, emphasizing your replication of visual techniques and drawing skills.\n   - The final collage should be submitted as a digital image or PDF file.\n\n4. **Reflection:**\n   - Accompany your collage with a one-page written reflection or voice recording explaining:\n     - How the binomial theorem and counting principles are represented visually.\n     - The connection between the mathematical calculations and your artistic visuals.\n     - How this project helped you understand probability and combinatorial concepts better.\n\n---\n\n### Rubric:\n\n| Criteria                          | Excellent (4)                                             | Good (3)                                                  | Satisfactory (2)                                         | Needs Improvement (1)                                    |\n|----------------------------------|-----------------------------------------------------------|----------------------------------------------------------|----------------------------------------------------------|----------------------------------------------------------|\n| **Mathematical Accuracy**          | All binomial expansions, counting principles, & probabilities are mathematically correct and clearly shown. | Minor errors in calculations or explanations but mostly correct. | Some errors, partial understanding demonstrated.         | Major errors or missing/incomplete mathematical content. |\n| **Visual & Digital Art Integration** | Artfully integrates diagrams with digital drawing; visuals enhance understanding dramatically. | Good use of diagrams and digital art; minor areas lack clarity. | Some visual elements present; art does not clearly represent math concepts. | Visuals are unclear or not related effectively to content.|\n| **Creativity & Visual Technique**  | Highly creative and skillful use of digital and drawing techniques; visually striking collage. | Good creativity and use of drawing skills; composition is clear. | Basic creativity; limited use of digital tools or drawing skills.              | Little creativity or effort in visual presentation.      |\n| **Clarity & Explanation**          | Written/recorded reflection clearly explains math-visual link, shows deep understanding. | Reflection explains connections but with minor ambiguities or omissions. | Reflection is vague or incomplete; unclear connections.  | No reflection or reflection does not relate to project.  |\n| **Presentation & Neatness**        | Collage is very well-organized, labeled, and easy to read; professionally presented. | Mostly organized and legible; minor issues with labeling or layout. | Some organization issues; difficult to follow at times.  | Disorganized, messy, or incomplete presentation.          |\n\n---\n\nThis homework will help you leverage your drawing and digital skills to overcome challenges in understanding math, especially combinatorics and probability, by making abstract concepts visual and integrated with your artistic strengths.', 'Here are the detailed homework instructions and rubric for the quest **Probability Games with Digital Design** focusing on skills in spatial probability, event representations, experiments, and creating an interactive digital gameboard showing problem setups and outcomes:\n\n---\n\n### Homework Instructions: Probability Games with Digital Design\n\n#### Objective:\nCreate a digital interactive “gameboard” that demonstrates your understanding of spatial probability concepts, event representations, and probability experiments. Your gameboard should visually and interactively present the set-up of at least three different probability experiments/games that involve spatial probability scenarios.\n\n#### Requirements:\n\n1. **Selection of Probability Games:**\n   - Choose at least three probability games or experiments that involve spatial probability concepts. Examples might include:\n     - Tossing coins and calculating outcomes in a spatial layout.\n     - Rolling dice and showing possible event spaces.\n     - Spinner games with partitioned sectors representing different probabilities.\n     - Any other game involving spatial arrangement or positioning affecting probability.\n\n2. **Design of the Interactive Gameboard:**\n   - Use digital design tools (such as drawing software, interactive digital presentation tools, or simple coding platforms) to create your gameboard.\n   - Represent all events clearly in a spatial format:\n     - Visual layouts should show where different outcomes occur spatially.\n     - Use interactive elements (clickable areas, sliders, or animations) to simulate experiments or reveal probabilities.\n   - Include labeled representations of events, sample spaces, and outcomes.\n\n3. **Experiment Simulations:**\n   - For each game, include a way to simulate the experiment digitally:\n     - For example, simulate spinning a spinner, rolling dice, or tossing coins and show the outcomes on the board.\n   - Show how events occur over multiple trials.\n\n4. **Probability Calculations and Representation:**\n   - Calculate the theoretical probability of key events visually on the gameboard.\n   - Display numerical probability results using digital text fields or clear graphical elements.\n   - Compare experimental results with theoretical probabilities by running simulated trials.\n\n5. **Explanation and Reflection:**\n   - Include a short written or digital text explanation for each game:\n     - Describe the rules, the spatial setup, and the associated probability concepts.\n     - Reflect on how representing the events spatially helped your understanding of the problem.\n     - Discuss any discrepancies between experimental and theoretical probabilities.\n\n6. **Creativity and Visual Appeal:**\n   - Use your drawing and digital design skills to make the gameboard visually engaging.\n   - Include well-crafted graphics, clear labels, and a professional layout.\n   - Make the interface user-friendly and intuitive.\n\n---\n\n### Rubric for Assessment\n\n| Criteria                      | Excellent (4)                                                      | Good (3)                                                     | Satisfactory (2)                                           | Needs Improvement (1)                                   |\n|-------------------------------|-------------------------------------------------------------------|--------------------------------------------------------------|------------------------------------------------------------|---------------------------------------------------------|\n| **Selection of Games**         | Three or more appropriate spatial probability games chosen clearly and creatively. | Three games chosen with some relevance to spatial probability. | Two games selected with partial spatial probability focus. | Fewer than two games or minimal connection to spatial probability. |\n| **Interactive Gameboard Design** | Gameboard is highly interactive, well-organized, and fully visualizes spatial probability concepts clearly. | Mostly interactive and organized, visualization mostly clear. | Basic interaction and visualization present.             | Poor interactivity and unclear or missing spatial visualization. |\n| **Experiment Simulation**      | Simulations are fully functional and visually demonstrate multiple trials effectively.  | Simulations mostly work and show trials with minor issues.   | Limited simulation, some trial representation.             | No or ineffective simulations of experiments.             |\n| **Probability Calculations**   | Theoretical and experimental probabilities are accurate and clearly presented with visual and numeric details. | Mostly accurate calculations with clear visual/numeric presentation. | Calculations present but with minor errors or unclear presentation. | Missing or inaccurate probability calculations.            |\n| **Explanation & Reflection**  | Clear, insightful explanations and reflections on spatial probability concepts and outcomes. | Adequate explanations with basic reflection.                | Limited explanation or superficial reflection.             | Missing or unclear explanation/reflection.                  |\n| **Creativity & Visual Appeal**| Design is highly creative, visually appealing, and professionally formatted. | Design is visually pleasing with adequate creativity.       | Basic design skills shown but less creative or neat.       | Poor design, unclear or visually unappealing presentation. |\n\n---\n\nPlease complete this homework by designing an engaging digital probability gameboard that illustrates spatial probability concepts interactively and visually, integrating your digital drawing strengths to overcome the challenge of representing mathematical ideas.\n\nIf you need suggestions about digital tools or examples, feel free to ask!\n\n---\n\nThis detailed instruction aligns with your quest skills for spatial probability, probability experiments, and digital interaction designs. It suits your visual and digital learning style while linking directly to the math concepts you are addressing visually in your long-term goals.', 'Here are the detailed homework instructions and rubric for the quest "Conic Sections Illustrated":\n\n---\n\n### Quest: Conic Sections Illustrated\n\n**Skills Focus:**  \n- Parabolas  \n- Ellipses  \n- Hyperbolas  \n- Parametric Equations  \n- Creating a series of digital illustrations for each conic section  \n\n---\n\n### Homework Instructions:\n\n1. **Overview:**  \n   Create a digital art series that visually represents and explains the four main conic sections: parabolas, ellipses, hyperbolas, and their parametric equations. Your illustrations should clearly demonstrate the unique features and properties of each conic section through precise and creative digital drawings.\n\n2. **Part 1: Parabolas**  \n   - Illustrate the general shape of a parabola based on its standard equation.\n   - Show the focus, directrix, and axis of symmetry visually.\n   - Use colors and labels to highlight these parts.\n   - Include a parametric equation illustration: demonstrate the motion of a point tracing the parabola digitally.\n\n3. **Part 2: Ellipses**  \n   - Create accurate representations of ellipses using their standard form equations.\n   - Illustrate the foci and major/minor axes clearly.\n   - Use shading or color gradients to emphasize the shape and properties.\n   - Include a parametric drawing to show how the ellipse is traced parametrically.\n\n4. **Part 3: Hyperbolas**  \n   - Draw hyperbolas clearly showing the two branches.\n   - Label asymptotes, vertices, and foci.\n   - Use digital tools to replicate reflections or precision line work around the asymptotes.\n   - Include a parametric curve illustration completing the hyperbola’s shape.\n\n5. **Part 4: Digital Techniques & Presentation**  \n   - Use your digital drawing skills to make each illustration visually engaging and clear.\n   - Employ layers, transparency, and digital brushes to enhance precision.\n   - Combine mathematical accuracy with artistic design to create visually compelling infographics.\n   - Add textual explanations alongside visuals to describe each conic section’s key concepts.\n\n6. **Submission Requirements:**  \n   - Submit a digital PDF or slideshow with all illustrations and accompanying explanations.\n   - Each conic section should have its own clearly labeled page or slide.\n   - Include your name and date on the cover page.\n\n---\n\n### Rubric for Assessment:\n\n| Criteria                     | Excellent (4)                                        | Good (3)                                             | Fair (2)                                           | Needs Improvement (1)                             |\n|------------------------------|----------------------------------------------------|-----------------------------------------------------|---------------------------------------------------|--------------------------------------------------|\n| **Mathematical Accuracy**     | Equations and features are perfectly accurate and labeled correctly | Mostly accurate with minor labeling errors          | Some inaccuracies or missing labels               | Many inaccuracies and lack of labels             |\n| **Visual Representation**     | Clear and precise illustrations with excellent use of digital tools | Clear illustration, some minor detail missing       | Basic illustrations, lacks precision or clarity   | Illustrations unclear or incorrect                |\n| **Parametric Equation Visualization** | Parametric tracing is clearly shown and explained | Parametric tracing shown but explanation is incomplete | Parametric illustrated but lacks clarity         | Parametric aspect missing or incorrect            |\n| **Creativity & Digital Skill Use** | Highly creative with advanced digital techniques, professional look | Good use of digital techniques, visually appealing  | Basic digital techniques, minimal creativity      | Poor digital execution, minimal or no creativity  |\n| **Presentation & Explanation** | Clear, concise explanations complement artwork well | Explanations are clear but less detailed             | Explanations present but somewhat unclear         | Explanations missing or confusing                 |\n\n---\n\nThis homework will help you merge your strengths in drawing and digital art with essential mathematical concepts, strengthening your understanding of conic sections while building a visual math portfolio.\n\nIf you want, I can also provide tips on digital tools or templates you might use for this project.', 'Here are detailed homework instructions and a rubric for your "Polar Coordinates and Graphs: Artistic Transformations" quest, designed to match your strengths in drawing and digital visual skills while addressing your interest in visual learning and math concepts:\n\n---\n\n### Homework Instructions: Polar Coordinates and Graphs — Artistic Transformations\n\n**Objective:**  \nCreate a dynamic visual project that explores polar coordinates through artistic transformations. Your work will demonstrate understanding of polar equations by converting Cartesian graphics into compelling polar visualizations, blending mathematical precision with your drawing and digital art skills.\n\n---\n\n#### Part 1: Understanding Polar Coordinates and Graphing\n\n1. **Review** the foundational concepts of polar coordinates: how points are represented by a radius (r) and angle (θ), and how they differ from Cartesian coordinates.\n\n2. **Graph Basic Polar Equations:**  \n   - Plot at least 3 different types of polar graphs manually (on graph paper or digitally), such as rose curves (r = a * cos(kθ)), circles (r = a), and limacons (r = a ± b * cosθ).  \n   - Label key points, axes (angle markers), and identify symmetry and periodicity.\n\n3. **Create a Visual Comparison:**  \n   - Draw a simple Cartesian graph and its equivalent polar graph side-by-side for one function, showing transformation and how the shape changes in polar form.\n\n---\n\n#### Part 2: Artistic Transformations Using Polar Graphs\n\n1. **Select a Favorite Cartesian Drawing or Shape** you’ve previously done or a simple shape you enjoy drawing.\n\n2. **Transform it into Polar:**  \n   - Using digital drawing tools, reimagine your chosen shape using polar coordinates. This can involve:  \n     - Mapping the shape’s points into polar form  \n     - Using polar equations creatively to reinterpret the shape’s outline or texture  \n     - Applying dynamic transformations such as rotation and scaling to create moving or evolving visuals.\n\n3. **Add Visual Enhancements:**  \n   - Incorporate colors, line thickness, and shading to emphasize the transformation from Cartesian to polar space.\n\n4. **Include Mathematical Annotations:**  \n   - Annotate your artwork with the polar formulas governing key features, angles, or curves.\n\n---\n\n#### Part 3: Reflection and Presentation\n\n1. **Write a brief artist’s statement (approx. 200-300 words):**  \n   - Discuss challenges and discoveries in combining drawing with polar coordinate graphing.  \n   - Explain how visualizing math concepts transformed your understanding of both the coordinate systems and artistic expression.\n\n2. Prepare your work for digital presentation (JPEG, PNG, or PDF) suitable for sharing.\n\n---\n\n### Submission Format:\n\n- Submit your plotted graphs and transformed drawing as digital images.\n- Include your artist’s statement as a text document or integrated into the presentation file.\n\n---\n\n### Rubric for Evaluation:\n\n| Criteria                              | Excellent (4)                                        | Good (3)                                               | Satisfactory (2)                                      | Needs Improvement (1)                               |\n|-------------------------------------|-----------------------------------------------------|--------------------------------------------------------|------------------------------------------------------|-----------------------------------------------------|\n| **Accuracy of Polar Graphing**      | Polar graphs are precisely plotted and fully labeled with clear mathematical correctness. | Graphs are mostly accurate with minor errors in detail or labeling. | Basic shapes graphed, but some key details or labeling are missing or incorrect. | Incomplete or incorrect graphing of polar equations. |\n| **Artistic Transformation & Creativity** | Creative and visually striking transformation showing deep integration of polar concepts with drawing. | Good use of polar concepts in art with thoughtful visual approach. | Some evidence of artistic transformation, but limited creative exploration. | Minimal or unclear transformation between coordinate systems. |\n| **Use of Digital Tools & Visual Style** | Expert use of digital tools; colors, line work, and design elements enhance clarity and appeal. | Effective digital use with adequate style and color coherence. | Basic digital techniques applied with limited visual enhancement. | Digital work is minimal or detracts from the concept. |\n| **Mathematical Communication**      | Clear annotations of polar equations with accurate descriptions linked to the artwork. | Annotations present but occasionally unclear or incomplete. | Limited or somewhat unclear mathematical explanation. | No mathematical annotations or unrelated comments. |\n| **Reflection Quality**               | Insightful, well-written reflection combining art and math learning with personal insight. | Clear reflection with relevant considerations about the process. | Basic reflection with limited depth or connection to learning. | Missing or unclear reflection on the project. |\n\n---\n\nIf you have questions or need help incorporating your digital drawing skills with math concepts, feel free to reach out. This homework will solidify your understanding of polar coordinates while leveraging your visual and digital strengths. Good luck!', 'Homework Instructions for Quest: 3D Coordinate Systems & Vectors in Space\n\nObjective:\nCreate a digital artwork that demonstrates your understanding of the 3-dimensional coordinate systems, vectors in space, and the cross product of vectors. This project integrates your strengths in replicating visual techniques and drawing with your interest in digital learning, helping deepen your grasp of 3D spatial concepts and vector operations through visual representation.\n\nInstructions:\n1. Concept Review:\n   - Review the concepts of the 3D coordinate system, including how to plot points in space using (x, y, z) coordinates.\n   - Study vectors in three dimensions, focusing on vector notation, vector addition, scalar multiplication, and the significance of direction and magnitude.\n   - Understand the cross product of two vectors, learning to compute it algebraically and interpret it geometrically as a vector perpendicular to the plane defined by the two original vectors.\n\n2. Planning Your Artwork:\n   - Choose a theme or scenario that can naturally incorporate 3D vectors and coordinate systems (e.g., spatial arrangement of objects, forces acting in a three-dimensional framework, or abstract representations of vector operations).\n   - Sketch preliminary designs digitally or on paper, focusing on the spatial relation of points and vectors.\n\n3. Digital Artwork Creation:\n   - Use digital drawing tools that allow layering, shading, and perspective to create depth and dimension in your artwork.\n   - Include at least three different vectors originating from a common point or illustrating vector addition.\n   - Depict the 3D coordinate axes clearly and label them.\n   - Illustrate the cross product by showing two vectors and their resulting vector perpendicular to their plane.\n   - Incorporate color coding or stylistic elements to differentiate vectors and coordinate axes.\n   - Ensure your artwork effectively communicates the mathematical concepts visually.\n\n4. Annotation and Explanation:\n   - Add concise labels and explanations directly integrated into the artwork to describe the vectors, coordinate points, and the cross product.\n   - Include a brief written summary (150-200 words) explaining the mathematical concepts depicted and how your artwork represents them.\n\n5. Submission:\n   - Submit your digital artwork file in a common format (e.g., PNG, JPEG, or PDF).\n   - Submit your written summary as a separate document or included in the artwork file.\n\nRubric:\n- Conceptual Accuracy (30 points):\n  - Correct depiction and labeling of 3D coordinate axes (10 points)\n  - Accurate representation of vectors including correct direction and magnitude (10 points)\n  - Correct depiction and explanation of the cross product and resultant vector (10 points)\n\n- Visual and Artistic Quality (25 points):\n  - Effective use of digital drawing tools to represent depth and 3D arrangement (10 points)\n  - Clear, neat, and visually engaging artwork using color and stylistic elements (10 points)\n  - Integration of mathematical labels and annotations into the artwork (5 points)\n\n- Creativity and Originality (20 points):\n  - Original theme or concept choice in representing vectors and 3D systems (10 points)\n  - Innovative use of visual techniques to communicate mathematical ideas (10 points)\n\n- Written Explanation (15 points):\n  - Clarity and completeness in the description of the mathematical concepts (10 points)\n  - Connection between visual elements and math concepts is clear and insightful (5 points)\n\n- Following Instructions and Presentation (10 points):\n  - Completeness of submission including artwork and summary (5 points)\n  - Proper file format and presentation quality (5 points)\n\nTotal: 100 points\n\nThis homework will help you visually and digitally master the concepts of 3D coordinate systems and vectors, addressing both your strengths and challenges, and progressing you toward your goal of integrating digital art with mathematical concepts.', 'Here are the detailed homework instructions and rubric for the quest **Portfolio Assembly: Visual Math Showcase** focusing on curating, refining, and presenting a digital art portfolio covering all key pre-calculus concepts:\n\n---\n\n### Homework Instructions: Portfolio Assembly — Visual Math Showcase\n\n**Objective:**  \nCreate a curated digital art portfolio that visually illustrates and explains key pre-calculus concepts you have learned throughout the course. Use your drawing skills and digital tools to make math concepts accessible and visually engaging.\n\n**Steps:**\n\n1. **Curate Your Works:**  \n   - Gather all your digital artworks created throughout the course that represent pre-calculus topics.  \n   - Ensure to include a wide range of key concepts such as functions, graphs, trigonometry, matrices, complex numbers, sequences, and vectors.\n\n2. **Refine and Enhance:**  \n   - Review each piece and refine details using digital tools for clarity and visual appeal.  \n   - Incorporate precise illustrations that replicate or adapt visual math techniques covered in class.  \n   - Make sure the mathematical accuracy is maintained or improved in your visual representations.\n\n3. **Add Clear Explanations:**  \n   - For each artwork, write a concise but thorough explanation of the corresponding pre-calculus concept.  \n   - The explanation should clarify the math idea in your own words and how the art visually represents it.  \n   - Use visual and digital learning styles to present the explanations alongside the images effectively, combining text and visuals.\n\n4. **Organize Portfolio:**  \n   - Arrange your pieces in a logical sequence that mirrors the progression of the course units or themes.  \n   - Create a digital format portfolio that is easy to navigate (e.g., a slideshow, digital booklet, or webpage).\n\n5. **Prepare a Showcase Presentation:**  \n   - Create a presentation summarizing the portfolio highlights, demonstrating your understanding of how art helps explain math concepts.  \n   - Practice explaining the key ideas using your visual art as support.  \n   - Be ready to share this in digital format.\n\n---\n\n### Rubric for Assessment:\n\n| Criteria                       | Excellent (4)                                      | Good (3)                                     | Fair (2)                                     | Needs Improvement (1)                        |\n|-------------------------------|--------------------------------------------------|----------------------------------------------|----------------------------------------------|----------------------------------------------|\n| **Coverage of Concepts**       | Includes comprehensive artworks covering all key pre-calculus concepts thoroughly. | Covers most key concepts with clear focus.  | Includes some concepts but lacks key areas. | Very limited coverage of pre-calculus topics. |\n| **Visual Quality & Precision** | Artwork is highly detailed, clear, and creatively uses digital tools with strong replication of math visuals. | Artwork is neat and mostly precise with competent digital enhancements. | Artwork is basic with minimal refinement or digital enhancement. | Artwork lacks clarity and refinement; poor digital execution. |\n| **Mathematical Accuracy**      | Concepts are mathematically accurate and well-represented visually. | Mostly accurate with minor visual/math inconsistencies. | Some inaccuracies or unclear visual math connections. | Many math errors or unclear visualizations.  |\n| **Explanations**               | Explanations are insightful, accurate, and effectively link art to math concepts. | Explanations are clear and mostly accurate. | Explanations are somewhat clear but lacking depth or clarity. | Explanations are missing, unclear, or inaccurate. |\n| **Portfolio Organization**     | Portfolio is logically organized with smooth flow and easy navigation. | Portfolio mostly organized with clear sequence. | Some organizational issues; somewhat confusing to follow. | Disorganized portfolio with poor flow.       |\n| **Presentation Readiness**    | Presentation is well-prepared, confident, and uses the portfolio to clearly communicate ideas. | Presentation is prepared with some clarity and engagement. | Presentation is somewhat prepared but lacks clarity or confidence. | Unprepared presentation; unclear communication. |\n\n---\n\nThis homework task leverages your strength in drawing and digital visual techniques while requiring you to engage deeply with the mathematical content. It also addresses your weakness in math by forcing conceptual understanding through visuals.\n\nIf you want, I can provide tips on how to balance the use of visuals and math explanations effectively or how to organize your digital portfolio format. Would you like that?']

# %%
len(output)
# Out:
# 18

# %%
output[0].Name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 output[0].Name
#
# AttributeError: 'str' object has no attribute 'Name'

# %%
output.model_dump_json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 output.model_dump_json()
#
# AttributeError: 'list' object has no attribute 'model_dump_json'
