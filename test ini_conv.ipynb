# %%
import json

from assistants import ini_conv
from models import student

# %%
golden = student.Student(
    student_id='golden',
    first_name='golden',
    last_name='huang',
    enrollments = ['123'],
    grade=10)

# %%
golden_ini_conv = ini_conv(golden, assis_id='asst_bmsuvfNCaHJYmqTlnT52AzXE')

# %%
ini_resp = golden_ini_conv.initiate()
# Out:
# messages: {
#   "response": "Hello Golden Huang, it’s great to meet you! As you're in 10th grade, I'd love to hear more about what subjects or hobbies excite you, as well as any recent challenges and successful experiences you’d like to share.",
#   "Strengths": [],
#   "Weaknesses": [],
#   "Interests": [],
#   "Learning_Styles": []
# }

# %%
ini_resp = json.loads(ini_resp)

# %%
ini_resp['response']
# Out:
# "Hello Golden Huang, it’s great to meet you! As you're in 10th grade, I'd love to hear more about what subjects or hobbies excite you, as well as any recent challenges and successful experiences you’d like to share."

# %%
ini_resp['Strengths']
# Out:
# []

# %%
golden_ini_conv.student
# Out:
# Student(student_id='golden', first_name='golden', last_name='huang', enrollments=['123'], grade=10, strength=None, weakness=None, interest=None, learning_style=None, long_term_goal=[], quests=[])
