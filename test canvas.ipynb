# %%
from canvas import *
API_URL = "https://byu.instructure.com"
API_KEY = "7407~xUaKTcWeTuw8k32NGmtteRC2NPaWz2kca7wXV4YAUu3QYctwFVLTzMznPC9wJTVF"
pre_calc = Course(30971, API_URL, API_KEY)

# %%
pre_calc.modules[0].items
# Out:
# [<canvas.Course.Module.File at 0x1048956a0>,
#  <canvas.Course.Module.File at 0x1047b7ed0>,
#  <canvas.Course.Module.File at 0x1047b7610>,
#  <canvas.Course.Module.File at 0x1047a76f0>,
#  <canvas.Course.Module.File at 0x1047a7490>,
#  <canvas.Course.Module.File at 0x104750b90>,
#  <canvas.Course.Module.File at 0x10479bdf0>,
#  <canvas.Course.Module.File at 0x10479bce0>,
#  <canvas.Course.Module.Page at 0x104895550>,
#  <canvas.Course.Module.Assignment at 0x104895940>,
#  <canvas.Course.Module.Page at 0x1048ec550>,
#  <canvas.Course.Module.Quiz at 0x1048946e0>,
#  <canvas.Course.Module.Discussion at 0x104895be0>]

# %%
test_js = course_to_json(pre_calc)

# %%
type(test_js)
# Out:
# str

# %%
with open('pre_calc.json', 'w') as f:
    f.write(test_js)

# %%
from assistants import *
