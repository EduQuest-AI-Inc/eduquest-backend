# %%
from assistants import create_class
# from models import period
from pydantic import BaseModel
from typing import List

class Period():
    def __init__(self, period_id,
                 initial_conversation_assistant_id,
                 update_assistant_id,
                 ltg_assistant_id,
                 teacher_id,
                 vector_store_id,
                 course,
                 file_urls):

        self.period_id=period_id
        self.initial_conversation_assistant_id=initial_conversation_assistant_id
        self.update_assistant_id=update_assistant_id
        self.ltg_assistant_id=ltg_assistant_id
        self.teacher_id=teacher_id
        self.vector_store_id=vector_store_id
        self.course=course
        self.file_urls=file_urls

# %%
test_period = Period(period_id=11111,
    initial_conversation_assistant_id='asst_bmsuvfNCaHJYmqTlnT52AzXE',
    update_assistant_id=None,
    ltg_assistant_id=str,
    teacher_id=111222,
    vector_store_id='vs_6859caa6c158819196617cfb270f3c43',
    course='wahoo',
    file_urls=[])

# %%
new_class = create_class(test_period.course)

# %%
new_class.create_ltg_assistant()
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 new_class.create_ltg_assistant()
#
# File ~/PycharmProjects/EduQuest/eduquest-backend/assistants.py:389, in create_class.create_ltg_assistant(self)
#     388 def create_ltg_assistant(self):
# --> 389     self.ltg_assistant = client.beta.assistants.create(
#     390         name=f"{self.class_name} LTG Assistant",
#     391         instructions=ltg_inst,
#     392         model="gpt-4.1-mini",
#     393         tools=[{"type": "file_search"}],
#     394         response_format={
#     395         "type": "json_schema",
#     396         "schema": ltg_response_format
#     397     }
#     398     )
#     399     self.ltg_assistant = client.beta.assistants.update(
#     400         assistant_id=self.ltg_assistant.id,
# ...
